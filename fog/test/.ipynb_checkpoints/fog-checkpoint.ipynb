# %%
from numpy.random import seed
seed(1)
from tensorflow import set_random_seed
set_random_seed(2)
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
from keras.models import Sequential
from keras.callbacks import ModelCheckpoint
from keras.layers import Dense
from keras.optimizers import Adam, SGD
import matplotlib.pyplot as plt
# Out:
# /usr/local/Cellar/python3/3.6.3/Frameworks/Python.framework/Versions/3.6/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)
# Using TensorFlow backend.

# %% [markdown]
# ### Data Preparation

# %%
def prepare(stationfile, lead_hrs=3):
    """
    lead_hrs = minimum # of hours before observation used in prediction (integer)
    """

    # parsing and cleaning data from CSV file
    dateparse = lambda x: pd.datetime.strptime(x, '%Y-%m-%d %H:%M:%S')
    data = pd.read_csv(stationfile,low_memory=False, parse_dates=['valid'], date_parser=dateparse)
    data = data.dropna(0,how='any')
    list_vars = ['tmpf', 'relh', 'dwpf', 'drct', 'sknt', 'alti' , 'vsby']
    list_hours = ['1 hour', '2 hour', '3 hour', '4 hour', '5 hour', '6 hour', '7 hour', '8 hour', '9 hour', '10 hour', '11 hour', '12 hour']
    list_hours = list_hours[(lead_hrs-1):]
    features_list = ['{} {}'.format(var, hour) for var in list_vars for hour in list_hours]
    X = np.array(data[features_list])
    
    # setting low visibility rows to '1', others to '0' 
    data.loc[data['vsby'] < 1, 'vsby' ] = 1
    data.loc[data['vsby'] > 1, 'vsby' ] = 0
    Y = data['vsby']

    # Spliting into Training, Validation and Testing dataset
    X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.25, random_state=0)
    X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=0)

    # Normalizing Data
    scaler = StandardScaler()
    scaler.fit(X_train)
    X_train = scaler.transform(X_train)
    X_test = scaler.transform(X_test)
    X_val = scaler.transform(X_val)
        
    return X_train, X_test, X_val, y_train, y_test, y_val

# %% [markdown]
# ### Neural Network definition, training and prediction

# %%
def make_model(shape):
    model = Sequential()
    model.add(Dense(64, input_dim=shape, activation='relu', kernel_initializer = 'normal'))
    model.add(Dense(64, activation='relu'))
#     model.add(Dense(128, activation='relu'))
#     model.add(Dense(256, activation='relu'))    
#     model.add(Dense(128, activation='relu'))
#     model.add(Dense(64, activation='relu'))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

def train_model(model, X_train, X_val, y_train, y_val):
    checkpointer = ModelCheckpoint(filepath='weights.best.hdf5', verbose=1, save_best_only=True)
    model.fit(np.array(X_train), np.array(y_train), batch_size=1024,epochs=20, validation_data=(X_val, y_val), callbacks=[checkpointer], verbose=0)
    return model
    
def predict(model, X_test, y_test):    
    predictions = model.predict(X_test)
    predictions = (predictions > 0.5).astype(int)
    cm = confusion_matrix(y_test, predictions, labels=[0,1])
    return cm
    
def metrics(cm, metric):    
    tn, fp, fn, tp = cm.ravel()
    if metric == 'recall':
        return float(tp)/(tp+fn)
    if metric == 'specificity':
        return float(tn)/(tn+fp)
    if metric == 'precision':
        return float(tp)/(tp+fp)
    if metric == 'miss_rate':
        return float(fn)/(fn+tp)
    if metric == 'accuracy':
        return (float(tp)+tn)/(tp+tn+fp+fn)

# %% [markdown]
# ## Model Train and Run:

# %%
for airport in ['SUMU', 'SAEZ']: 
    for lead in range(1,9):
        print(airport, lead)
        X_train, X_test, X_val, y_train, y_test, y_val = prepare('{}.csv'.format(airport), lead_hrs=lead)
        model = make_model(X_train.shape[1])
        model = train_model(model, X_train, X_val, y_train, y_val)
        cm = predict(model, X_test, y_test)

        try:
            recall = metrics(cm,'recall')
        except ZeroDivisionError:
            recall = np.nan
        try:    
            precision = metrics(cm, 'precision')
        except ZeroDivisionError:
            precision = np.nan
            
        f = open('stats.csv', 'a+')
        header = 'airport,lead,recall,precision'
        string_out='{},{},{},{}\n'.format(airport,lead,recall,precision)
        f.write(string_out)
        f.close()

print('Done')
# Out:
# SUMU 1
#
# Epoch 00001: val_loss improved from inf to 0.11682, saving model to weights.best.hdf5
#
# Epoch 00002: val_loss improved from 0.11682 to 0.10180, saving model to weights.best.hdf5
#
# Epoch 00003: val_loss improved from 0.10180 to 0.09072, saving model to weights.best.hdf5
#
# Epoch 00004: val_loss improved from 0.09072 to 0.08571, saving model to weights.best.hdf5
#
# Epoch 00005: val_loss improved from 0.08571 to 0.08247, saving model to weights.best.hdf5
#
# Epoch 00006: val_loss improved from 0.08247 to 0.08000, saving model to weights.best.hdf5
#
# Epoch 00007: val_loss improved from 0.08000 to 0.07895, saving model to weights.best.hdf5
#
# Epoch 00008: val_loss improved from 0.07895 to 0.07895, saving model to weights.best.hdf5
#
# Epoch 00009: val_loss improved from 0.07895 to 0.07772, saving model to weights.best.hdf5
#
# Epoch 00010: val_loss improved from 0.07772 to 0.07754, saving model to weights.best.hdf5
#
# Epoch 00011: val_loss improved from 0.07754 to 0.07682, saving model to weights.best.hdf5
#
# Epoch 00012: val_loss did not improve
#
# Epoch 00013: val_loss improved from 0.07682 to 0.07664, saving model to weights.best.hdf5
#
# Epoch 00014: val_loss improved from 0.07664 to 0.07622, saving model to weights.best.hdf5
#
# Epoch 00015: val_loss did not improve
#
# Epoch 00016: val_loss did not improve
#
# Epoch 00017: val_loss improved from 0.07622 to 0.07608, saving model to weights.best.hdf5
#
# Epoch 00018: val_loss improved from 0.07608 to 0.07543, saving model to weights.best.hdf5
#
# Epoch 00019: val_loss did not improve
#
# Epoch 00020: val_loss did not improve
# SUMU 2
#
# Epoch 00001: val_loss improved from inf to 0.12216, saving model to weights.best.hdf5
#
# Epoch 00002: val_loss improved from 0.12216 to 0.10495, saving model to weights.best.hdf5
#
# Epoch 00003: val_loss improved from 0.10495 to 0.09788, saving model to weights.best.hdf5
#
# Epoch 00004: val_loss improved from 0.09788 to 0.09424, saving model to weights.best.hdf5
#
# Epoch 00005: val_loss improved from 0.09424 to 0.09190, saving model to weights.best.hdf5
#
# Epoch 00006: val_loss improved from 0.09190 to 0.09121, saving model to weights.best.hdf5
#
# Epoch 00007: val_loss improved from 0.09121 to 0.08936, saving model to weights.best.hdf5
#
# Epoch 00008: val_loss improved from 0.08936 to 0.08904, saving model to weights.best.hdf5
#
# Epoch 00009: val_loss improved from 0.08904 to 0.08821, saving model to weights.best.hdf5
#
# Epoch 00010: val_loss did not improve
#
# Epoch 00011: val_loss improved from 0.08821 to 0.08714, saving model to weights.best.hdf5
#
# Epoch 00012: val_loss did not improve
#
# Epoch 00013: val_loss improved from 0.08714 to 0.08695, saving model to weights.best.hdf5
#
# Epoch 00014: val_loss improved from 0.08695 to 0.08596, saving model to weights.best.hdf5
#
# Epoch 00015: val_loss improved from 0.08596 to 0.08551, saving model to weights.best.hdf5
#
# Epoch 00016: val_loss did not improve
#
# Epoch 00017: val_loss improved from 0.08551 to 0.08478, saving model to weights.best.hdf5
#
# Epoch 00018: val_loss did not improve
#
# Epoch 00019: val_loss did not improve
#
# Epoch 00020: val_loss did not improve
# SUMU 3
#
# Epoch 00001: val_loss improved from inf to 0.12095, saving model to weights.best.hdf5
#
# Epoch 00002: val_loss improved from 0.12095 to 0.10823, saving model to weights.best.hdf5
#
# Epoch 00003: val_loss improved from 0.10823 to 0.10119, saving model to weights.best.hdf5
#
# Epoch 00004: val_loss improved from 0.10119 to 0.09798, saving model to weights.best.hdf5
#
# Epoch 00005: val_loss improved from 0.09798 to 0.09706, saving model to weights.best.hdf5
#
# Epoch 00006: val_loss improved from 0.09706 to 0.09615, saving model to weights.best.hdf5
#
# Epoch 00007: val_loss improved from 0.09615 to 0.09497, saving model to weights.best.hdf5
#
# Epoch 00008: val_loss improved from 0.09497 to 0.09402, saving model to weights.best.hdf5
#
# Epoch 00009: val_loss improved from 0.09402 to 0.09348, saving model to weights.best.hdf5
#
# Epoch 00010: val_loss improved from 0.09348 to 0.09297, saving model to weights.best.hdf5
#
# Epoch 00011: val_loss did not improve
#
# Epoch 00012: val_loss improved from 0.09297 to 0.09258, saving model to weights.best.hdf5
#
# Epoch 00013: val_loss improved from 0.09258 to 0.09253, saving model to weights.best.hdf5
#
# Epoch 00014: val_loss did not improve
#
# Epoch 00015: val_loss did not improve
#
# Epoch 00016: val_loss did not improve
#
# Epoch 00017: val_loss improved from 0.09253 to 0.09118, saving model to weights.best.hdf5
#
# Epoch 00018: val_loss did not improve
#
# Epoch 00019: val_loss did not improve
#
# Epoch 00020: val_loss did not improve
# SUMU 4
#
# Epoch 00001: val_loss improved from inf to 0.12572, saving model to weights.best.hdf5
#
# Epoch 00002: val_loss improved from 0.12572 to 0.11517, saving model to weights.best.hdf5
#
# Epoch 00003: val_loss improved from 0.11517 to 0.10829, saving model to weights.best.hdf5
#
# Epoch 00004: val_loss improved from 0.10829 to 0.10621, saving model to weights.best.hdf5
#
# Epoch 00005: val_loss improved from 0.10621 to 0.10457, saving model to weights.best.hdf5
#
# Epoch 00006: val_loss improved from 0.10457 to 0.10378, saving model to weights.best.hdf5
#
# Epoch 00007: val_loss improved from 0.10378 to 0.10355, saving model to weights.best.hdf5
#
# Epoch 00008: val_loss improved from 0.10355 to 0.10242, saving model to weights.best.hdf5
#
# Epoch 00009: val_loss did not improve
#
# Epoch 00010: val_loss improved from 0.10242 to 0.10200, saving model to weights.best.hdf5
#
# Epoch 00011: val_loss improved from 0.10200 to 0.10140, saving model to weights.best.hdf5
#
# Epoch 00012: val_loss improved from 0.10140 to 0.10119, saving model to weights.best.hdf5
#
# Epoch 00013: val_loss improved from 0.10119 to 0.10118, saving model to weights.best.hdf5
#
# Epoch 00014: val_loss did not improve
#
# Epoch 00015: val_loss improved from 0.10118 to 0.10045, saving model to weights.best.hdf5
#
# Epoch 00016: val_loss did not improve
#
# Epoch 00017: val_loss improved from 0.10045 to 0.10016, saving model to weights.best.hdf5
#
# Epoch 00018: val_loss did not improve
#
# Epoch 00019: val_loss improved from 0.10016 to 0.10002, saving model to weights.best.hdf5
#
# Epoch 00020: val_loss improved from 0.10002 to 0.09974, saving model to weights.best.hdf5
# SUMU 5
#
# Epoch 00001: val_loss improved from inf to 0.14971, saving model to weights.best.hdf5
#
# Epoch 00002: val_loss improved from 0.14971 to 0.12306, saving model to weights.best.hdf5
#
# Epoch 00003: val_loss improved from 0.12306 to 0.11389, saving model to weights.best.hdf5
#
# Epoch 00004: val_loss improved from 0.11389 to 0.10997, saving model to weights.best.hdf5
#
# Epoch 00005: val_loss improved from 0.10997 to 0.10817, saving model to weights.best.hdf5
#
# Epoch 00006: val_loss improved from 0.10817 to 0.10686, saving model to weights.best.hdf5
#
# Epoch 00007: val_loss improved from 0.10686 to 0.10644, saving model to weights.best.hdf5
#
# Epoch 00008: val_loss improved from 0.10644 to 0.10584, saving model to weights.best.hdf5
#
# Epoch 00009: val_loss improved from 0.10584 to 0.10487, saving model to weights.best.hdf5
#
# Epoch 00010: val_loss improved from 0.10487 to 0.10407, saving model to weights.best.hdf5
#
# Epoch 00011: val_loss improved from 0.10407 to 0.10367, saving model to weights.best.hdf5
#
# Epoch 00012: val_loss did not improve
#
# Epoch 00013: val_loss improved from 0.10367 to 0.10364, saving model to weights.best.hdf5
#
# Epoch 00014: val_loss improved from 0.10364 to 0.10283, saving model to weights.best.hdf5
#
# Epoch 00015: val_loss improved from 0.10283 to 0.10272, saving model to weights.best.hdf5
#
# Epoch 00016: val_loss did not improve
#
# Epoch 00017: val_loss improved from 0.10272 to 0.10206, saving model to weights.best.hdf5
#
# Epoch 00018: val_loss did not improve
#
# Epoch 00019: val_loss improved from 0.10206 to 0.10198, saving model to weights.best.hdf5
#
# Epoch 00020: val_loss did not improve
# SUMU 6
#
# Epoch 00001: val_loss improved from inf to 0.17172, saving model to weights.best.hdf5
#
# Epoch 00002: val_loss improved from 0.17172 to 0.12218, saving model to weights.best.hdf5
#
# Epoch 00003: val_loss improved from 0.12218 to 0.11599, saving model to weights.best.hdf5
#
# Epoch 00004: val_loss improved from 0.11599 to 0.11279, saving model to weights.best.hdf5
#
# Epoch 00005: val_loss improved from 0.11279 to 0.11129, saving model to weights.best.hdf5
# Epoch 00006: val_loss improved from 0.11129 to 0.11012, saving model to weights.best.hdf5
#
# Epoch 00007: val_loss improved from 0.11012 to 0.10971, saving model to weights.best.hdf5
#
# Epoch 00008: val_loss improved from 0.10971 to 0.10919, saving model to weights.best.hdf5
#
# Epoch 00009: val_loss improved from 0.10919 to 0.10877, saving model to weights.best.hdf5
#
# Epoch 00010: val_loss improved from 0.10877 to 0.10824, saving model to weights.best.hdf5
#
# Epoch 00011: val_loss improved from 0.10824 to 0.10793, saving model to weights.best.hdf5
#
# Epoch 00012: val_loss improved from 0.10793 to 0.10779, saving model to weights.best.hdf5
#
# Epoch 00013: val_loss improved from 0.10779 to 0.10752, saving model to weights.best.hdf5
#
# Epoch 00014: val_loss improved from 0.10752 to 0.10705, saving model to weights.best.hdf5
#
# Epoch 00015: val_loss improved from 0.10705 to 0.10701, saving model to weights.best.hdf5
#
# Epoch 00016: val_loss improved from 0.10701 to 0.10670, saving model to weights.best.hdf5
#
# Epoch 00017: val_loss improved from 0.10670 to 0.10644, saving model to weights.best.hdf5
#
# Epoch 00018: val_loss improved from 0.10644 to 0.10617, saving model to weights.best.hdf5
#
# Epoch 00019: val_loss did not improve
#
# Epoch 00020: val_loss did not improve
# SUMU 7
#
# Epoch 00001: val_loss improved from inf to 0.14850, saving model to weights.best.hdf5
#
# Epoch 00002: val_loss improved from 0.14850 to 0.12359, saving model to weights.best.hdf5
#
# Epoch 00003: val_loss improved from 0.12359 to 0.11803, saving model to weights.best.hdf5
#
# Epoch 00004: val_loss improved from 0.11803 to 0.11561, saving model to weights.best.hdf5
#
# Epoch 00005: val_loss improved from 0.11561 to 0.11399, saving model to weights.best.hdf5
#
# Epoch 00006: val_loss improved from 0.11399 to 0.11255, saving model to weights.best.hdf5
#
# Epoch 00007: val_loss improved from 0.11255 to 0.11147, saving model to weights.best.hdf5
#
# Epoch 00008: val_loss improved from 0.11147 to 0.11108, saving model to weights.best.hdf5
#
# Epoch 00009: val_loss improved from 0.11108 to 0.11061, saving model to weights.best.hdf5
#
# Epoch 00010: val_loss improved from 0.11061 to 0.11001, saving model to weights.best.hdf5
#
# Epoch 00011: val_loss improved from 0.11001 to 0.10970, saving model to weights.best.hdf5
#
# Epoch 00012: val_loss improved from 0.10970 to 0.10927, saving model to weights.best.hdf5
#
# Epoch 00013: val_loss did not improve
#
# Epoch 00014: val_loss improved from 0.10927 to 0.10889, saving model to weights.best.hdf5
#
# Epoch 00015: val_loss improved from 0.10889 to 0.10882, saving model to weights.best.hdf5
#
# Epoch 00016: val_loss improved from 0.10882 to 0.10822, saving model to weights.best.hdf5
#
# Epoch 00017: val_loss improved from 0.10822 to 0.10809, saving model to weights.best.hdf5
#
# Epoch 00018: val_loss did not improve
#
# Epoch 00019: val_loss improved from 0.10809 to 0.10758, saving model to weights.best.hdf5
#
# Epoch 00020: val_loss improved from 0.10758 to 0.10730, saving model to weights.best.hdf5

# %%
def plot(airport):
    plt.clf()
    df = pd.read_csv('stats.csv', names=['station','lead','recall','precision'])
    print df[df.station == airport]
    x = df[df.station == airport].lead

    plt.plot(x,df[df.station == airport].recall, label='Recall')
    plt.plot(x,df[df.station == airport].precision, label='Precision')
    plt.xlabel('Lead time in hours')
    plt.ylabel('Score')
    plt.legend().get_frame().set_edgecolor("k")
    plt.title('{} Airport'.format(airport))
    plt.show()

for airport in ['SUMU', 'SAEZ']: 
    plot(airport)
# Out:
#   station  lead  recall  precision
# 0    SUMU     1  0.4225   0.725322
# 1    SUMU     2  0.3525   0.618421
# 2    SUMU     3  0.3375   0.564854
# 3    SUMU     4  0.1800   0.566929
# 4    SUMU     5  0.1950   0.478528
# 5    SUMU     6  0.2000   0.496894
# 6    SUMU     7  0.1550   0.436620
# 7    SUMU     8  0.1850   0.406593
#    station  lead    recall  precision
# 8     SAEZ     1  0.632990   0.660215
# 9     SAEZ     2  0.558763   0.586580
# 10    SAEZ     3  0.503093   0.605459
# 11    SAEZ     4  0.395876   0.583587
# 12    SAEZ     5  0.418557   0.524548
# 13    SAEZ     6  0.247423   0.618557
# 14    SAEZ     7  0.288660   0.507246
# 15    SAEZ     8  0.259794   0.415842

# %%
dateparse = lambda x: pd.datetime.strptime(x, '%Y-%m-%d %H:%M:%S')
data = pd.read_csv('SUMU.csv',low_memory=False, parse_dates=['valid'], date_parser=dateparse)

# %%
data.head()
# Out:
#    Unnamed: 0               valid  tmpf  dwpf   relh   drct  sknt   alti  \
# 0           0 2011-01-01 02:00:00  68.0  62.6  82.86  100.0  10.0  29.97
# 1           1 2011-01-01 03:00:00  68.0  64.4  88.26   90.0   5.0  29.97
# 2           2 2011-01-01 04:00:00  68.0  64.4  88.26   70.0   5.0  29.97
# 3           3 2011-01-01 05:00:00  64.4  62.6  93.88   90.0   4.0  29.94
# 4           4 2011-01-01 07:00:00  64.4  62.6  93.88   50.0   5.0  29.94
#
#    vsby  tmpf 1 hour      ...       vsby 3 hour  vsby 4 hour  vsby 5 hour  \
# 0  6.21          NaN      ...               NaN          NaN          NaN
# 1  6.21         68.0      ...               NaN          NaN          NaN
# 2  6.21         68.0      ...               NaN          NaN          NaN
# 3  6.21         68.0      ...              6.21          NaN          NaN
# 4  6.21          NaN      ...              6.21         6.21         6.21
#
#    vsby 6 hour  vsby 7 hour  vsby 8 hour  vsby 9 hour  vsby 10 hour  \
# 0          NaN          NaN          NaN          NaN           NaN
# 1          NaN          NaN          NaN          NaN           NaN
# 2          NaN          NaN          NaN          NaN           NaN
# 3          NaN          NaN          NaN          NaN           NaN
# 4          NaN          NaN          NaN          NaN           NaN
#
#    vsby 11 hour  vsby 12 hour
# 0           NaN           NaN
# 1           NaN           NaN
# 2           NaN           NaN
# 3           NaN           NaN
# 4           NaN           NaN
#
# [5 rows x 93 columns]
